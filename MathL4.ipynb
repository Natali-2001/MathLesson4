# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
a = np.linspace(0.01, 0.02)
for k in [1, 2, 3]:
    plt.plot(a, k*np.pi/a)
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(0.01,0.02) 
plt.ylim(100,500)
# Out:
# (100.0, 500.0)
